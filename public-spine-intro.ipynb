# %% [markdown]
# # Third Sector and Civil Society (UK) data: Getting started
#
# In this notebook we learn where to find the data, how it was compiled, and how to begin to use it for research and analysis.

# %% [markdown]
# ## Data location
#
# Versions of the dataset are found on the project webpage https://uk-third-sector-database.github.io/data/
#
# The following code assumes you have downloaded the data and unzipped it into a folder called 'data' in the same directory as this notebook.

# %% [markdown]
# 1. Spine file: this contains the full set of civil society organisations found using the sources referenced.

# %%
# %pip install pandas
# %pip install IPython
import pandas as pd

from IPython.display import display
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/fionack/Library/Python/3.11/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/fionack/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: IPython in /Users/fionack/Library/Python/3.11/lib/python/site-packages (8.18.1)
# Requirement already satisfied: decorator in /Users/fionack/Library/Python/3.11/lib/python/site-packages (from IPython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/fionack/Library/Python/3.11/lib/python/site-packages (from IPython) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/fionack/Library/Python/3.11/lib/python/site-packages (from IPython) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/fionack/Library/Python/3.11/lib/python/site-packages (from IPython) (3.0.41)
# Requirement already satisfied: pygments>=2.4.0 in /Users/fionack/Library/Python/3.11/lib/python/site-packages (from IPython) (2.17.2)
# Requirement already satisfied: stack-data in /Users/fionack/Library/Python/3.11/lib/python/site-packages (from IPython) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /Users/fionack/Library/Python/3.11/lib/python/site-packages (from IPython) (5.14.0)
# Requirement already satisfied: pexpect>4.3 in /Users/fionack/Library/Python/3.11/lib/python/site-packages (from IPython) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/fionack/Library/Python/3.11/lib/python/site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/fionack/Library/Python/3.11/lib/python/site-packages (from pexpect>4.3->IPython) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/fionack/Library/Python/3.11/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython) (0.2.12)
# Requirement already satisfied: executing>=1.2.0 in /Users/fionack/Library/Python/3.11/lib/python/site-packages (from stack-data->IPython) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/fionack/Library/Python/3.11/lib/python/site-packages (from stack-data->IPython) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/fionack/Library/Python/3.11/lib/python/site-packages (from stack-data->IPython) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /Users/fionack/Library/Python/3.11/lib/python/site-packages (from asttokens>=2.1.0->stack-data->IPython) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
spine_df = pd.read_csv('data/public_spine.spine.csv')
# Out:
# /var/folders/kx/my6qjd410pg_mks04z_5dm3r0000gn/T/ipykernel_93567/3522471833.py:1: DtypeWarning: Columns (4,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   spine_df = pd.read_csv('data/public_spine.spine.csv')

# %%
print('The top 5 rows of the spine data are:')
display(spine_df.head())
print('\nThe summary statistics of the spine data are:')
display(spine_df.describe())
print(f'\nThe spine data has {spine_df.shape[0]} rows and {spine_df.shape[1]} columns.\n')
print(f'Spine data columns are: {list(spine_df.columns)}.\n')
# Out:
# The top 5 rows of the spine data are:
#              uid                           organisationname  \
# 0  GB-CHC-200009  THE RALPH LEVY CHARITABLE COMPANY LIMITED
# 1  GB-CHC-200012                  CHURCH AND POOR'S CHARITY
# 2  GB-CHC-200017                         THE SHOWERING FUND
# 3  GB-CHC-200023         MOSSWOOD MISSION HALL (TRUST 1188)
# 4  GB-CHC-200024       THE D'OYLY CARTE OPERA TRUST LIMITED
#
#                               normalisedname  \
# 0  THE RALPH LEVY CHARITABLE COMPANY LIMITED
# 1                   CHURCH AND POORS CHARITY
# 2                         THE SHOWERING FUND
# 3           MOSSWOOD MISSION HALL TRUST 1188
# 4        THE DOYLY CARTE OPERA TRUST LIMITED
#
#                                          fulladdress city  postcode  \
# 0                            5-6 DOWN STREET, LONDON  NaN   W1J 7AH
# 1  62 HIGH STREET, WRESTLINGWORTH, SANDY, BEDFORD...  NaN  SG19 2EP
# 2  PATHOLOGY SCIENCES PHASE 2 LEVEL 2, NORTH BRIS...  NaN  BS10 5NB
# 3                       41 CUMBERLEDGE HILL, RUGELEY  NaN  WS15 4SB
# 4  D'OYLY CARTE OPERA TRUST LTD, 1 NORTHUMBERLAND...  NaN  WC2N 5BW
#
#   registerdate removeddate
# 0   17/03/1961         NaN
# 1   22/06/1961         NaN
# 2   08/06/1961         NaN
# 3   22/06/1961         NaN
# 4   07/02/1961         NaN
# The summary statistics of the spine data are:
#                   uid organisationname normalisedname fulladdress    city  \
# count          804056           794620         794619      708272  315073
# unique         804056           759788         741561      556137    8628
# top     GB-CHC-200009          Deleted        DELETED        -, -  LONDON
# freq                1             1775           1775        9349   76259
#
#         postcode registerdate removeddate
# count     754841       759227      392767
# unique    373738        29801       13907
# top     EC1A 9EJ   01/01/1992  02/06/2012
# freq       15505        18679       19596
# The spine data has 804056 rows and 8 columns.
#
# Spine data columns are: ['uid', 'organisationname', 'normalisedname', 'fulladdress', 'city', 'postcode', 'registerdate', 'removeddate'].

# %% [markdown]
# 2. Matches: this file contains the linkages we found between organisation on the spine, and registrations elsewhere for the same organisation. These can be due to registration within the same regulator, and across regulators.

# %%
matches_df = pd.read_csv('data/public_spine.matches.csv')
# Out:
# /var/folders/kx/my6qjd410pg_mks04z_5dm3r0000gn/T/ipykernel_93567/2978414177.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   matches_df = pd.read_csv('data/public_spine.matches.csv')

# %%
print(f'\nThe matches data has {matches_df.shape[0]} rows and {matches_df.shape[1]} columns.\n')
print(f'matches data columns are: {list(matches_df.columns)}.\n')
print('The top 5 rows of the matches data are:')
display(matches_df.head())
print('\nThe summary statistics of the matches data are:')
display(matches_df.describe())
# Out:
# The matches data has 112879 rows and 8 columns.
#
# matches data columns are: ['uid', 'orgA_id_in_source', 'orgA_source', 'orgA_uid', 'orgB_id_in_source', 'orgB_source', 'orgB_uid', 'match_type'].
#
# The top 5 rows of the matches data are:
#              uid orgA_id_in_source orgA_source       orgA_uid  \
# 0  GB-CHC-200009            200009        CCEW  GB-CHC-200009
# 1  GB-CHC-200024            200024        CCEW  GB-CHC-200024
# 2  GB-CHC-200048            200048        CCEW  GB-CHC-200048
# 3  GB-CHC-200103            200103        CCEW  GB-CHC-200103
# 4  GB-CHC-200103            200103        CCEW  GB-CHC-200103
#
#   orgB_id_in_source           orgB_source         orgB_uid  \
# 0          00686799                    CH  GB-COH-00686799
# 1          00682766                    CH  GB-COH-00682766
# 2          00683275                    CH  GB-COH-00683275
# 3             A2072  SocialHousingEngland    GB-SHPE-A2072
# 4             A2072  SocialHousingEngland    GB-SHPE-A2072
#
#                  match_type
# 0  companyid - id_in_source
# 1  companyid - id_in_source
# 2  companyid - id_in_source
# 3                       ftc
# 4            name - housing
# The summary statistics of the matches data are:
#                    uid  orgA_id_in_source orgA_source        orgA_uid  \
# count           111930             112879      112879          112879
# unique           99143              99143           7           99144
# top     GB-CHC-1066001            1201116        CCEW  GB-CHC-1201116
# freq               679                854       73967             854
#
#        orgB_id_in_source orgB_source       orgB_uid match_type
# count             112879      112879         112879     112879
# unique            102452           9         102621          7
# top         CS2003002877          CH  GB-SHPE-A2406        ftc
# freq                   7       78101              7      63343

# %% [markdown]
# If a match is assured, using the rules described in the associated documents, then the 'uid' is the same as a row in the spine, for example uid GB-CHC-200009:

# %%
display(matches_df[matches_df['uid'] == 'GB-CHC-200009'])
# Out:
#              uid orgA_id_in_source orgA_source       orgA_uid  \
# 0  GB-CHC-200009            200009        CCEW  GB-CHC-200009
#
#   orgB_id_in_source orgB_source         orgB_uid                match_type
# 0          00686799          CH  GB-COH-00686799  companyid - id_in_source

# %%
display(spine_df[spine_df['uid']=='GB-CHC-200009'])
display(spine_df[spine_df['uid']=='GB-COH-00686799'])
# Out:
#              uid                           organisationname  \
# 0  GB-CHC-200009  THE RALPH LEVY CHARITABLE COMPANY LIMITED
#
#                               normalisedname              fulladdress city  \
# 0  THE RALPH LEVY CHARITABLE COMPANY LIMITED  5-6 DOWN STREET, LONDON  NaN
#
#   postcode registerdate removeddate
# 0  W1J 7AH   17/03/1961         NaN
# Empty DataFrame
# Columns: [uid, organisationname, normalisedname, fulladdress, city, postcode, registerdate, removeddate]
# Index: []

# %% [markdown]
# So 'The Ralph Levy Charitable Company Limited' is on the spine, but the matched organisation 'GB-COH-00686799' is not, since these have been found to be the same organisation.
#
# The 'match_type' field in public_spine.matches.csv shows how the match was determined; in this case 'companyid - id_in_source' comes from the Charity Commission register having a note of the associated record at Companies House.

# %% [markdown]
# 3. Supplementary: A third csv completes the set. This contains extra name and address data about the organisations on the spine (or matched to the spine), for example a previous address or alternative name.

# %%
supplementary_df = pd.read_csv('data/public_spine.supplementary.csv')

# %%
print(f'\nThe supplementary data has {supplementary_df.shape[0]} rows and {supplementary_df.shape[1]} columns.\n')
print(f'supplementary data columns are: {list(supplementary_df.columns)}.\n')
print('The top 5 rows of the supplementary data are:')
display(supplementary_df.head())
print('\nThe summary statistics of the supplementary data are:')
display(supplementary_df.describe())
# Out:
# The supplementary data has 1163448 rows and 9 columns.
#
# supplementary data columns are: ['uid', 'organisationname', 'normalisedname', 'fulladdress', 'city', 'postcode', 'registerdate', 'removeddate', 'source'].
#
# The top 5 rows of the supplementary data are:
#                uid                            organisationname  \
# 0    GB-CHC-200009                                         NaN
# 1    GB-CHC-200009                                         NaN
# 2    GB-CHC-200009                                         NaN
# 3  GB-COH-00686799  RALPH LEVY CHARITABLE COMPANY LIMITED(THE)
# 4  GB-COH-00686799                                         NaN
#
#                               normalisedname                     fulladdress  \
# 0                                        NaN  14 CHESTERFIELD STREET, LONDON
# 1                                        NaN          1 HINDE STREET, LONDON
# 2                                        NaN          116 PICCADILLY, LONDON
# 3  RALPH LEVY CHARITABLE COMPANY LIMITED THE    1 HINDE STREET, HINDE STREET
# 4                                        NaN                 5-6 DOWN STREET
#
#      city postcode registerdate removeddate source
# 0     NaN  W1J 5JN          NaN         NaN   CCEW
# 1     NaN  W1U 2AY          NaN         NaN   CCEW
# 2     NaN  W1J 7BJ          NaN         NaN   CCEW
# 3  LONDON  W1U 2AY          NaN         NaN     CH
# 4  LONDON      NaN          NaN         NaN     CH
# The summary statistics of the supplementary data are:
#                    uid organisationname normalisedname  \
# count          1163448           324512         324505
# unique          517580           292929         286077
# top     GB-CHC-1052330     VILLAGE HALL   VILLAGE HALL
# freq               452              368            368
#
#                                               fulladdress    city postcode  \
# count                                              546543   83936   480017
# unique                                             477537    4182   278255
# top     MILESTONE HOUSE 18 NURSERY COURT, KIBWORTH HAR...  LONDON  SE1 7HR
# freq                                                  888   16249     3867
#
#        registerdate removeddate   source
# count        223998       48650  1163448
# unique        14211        5976       10
# top      31/12/2012  04/03/2022     CCEW
# freq          16677         679   686137

# %% [markdown]
# Using the same example of the Ralph Levey Charitable Company, we find the following data in the supplementary csv for the organisation, from both the Charity Commission (CCEW) and Companies House (CH):

# %%
display(supplementary_df[supplementary_df['uid']=='GB-CHC-200009'])
display(supplementary_df[supplementary_df['uid']=='GB-COH-00686799'])
# Out:
#              uid organisationname normalisedname  \
# 0  GB-CHC-200009              NaN            NaN
# 1  GB-CHC-200009              NaN            NaN
# 2  GB-CHC-200009              NaN            NaN
# 7  GB-CHC-200009              NaN            NaN
#
#                       fulladdress city postcode registerdate removeddate  \
# 0  14 CHESTERFIELD STREET, LONDON  NaN  W1J 5JN          NaN         NaN
# 1          1 HINDE STREET, LONDON  NaN  W1U 2AY          NaN         NaN
# 2          116 PICCADILLY, LONDON  NaN  W1J 7BJ          NaN         NaN
# 7                             NaN  NaN      NaN   22/06/1961         NaN
#
#   source
# 0   CCEW
# 1   CCEW
# 2   CCEW
# 7   CCEW
#                uid                            organisationname  \
# 3  GB-COH-00686799  RALPH LEVY CHARITABLE COMPANY LIMITED(THE)
# 4  GB-COH-00686799                                         NaN
# 5  GB-COH-00686799                                         NaN
# 6  GB-COH-00686799                                         NaN
#
#                               normalisedname                   fulladdress  \
# 3  RALPH LEVY CHARITABLE COMPANY LIMITED THE  1 HINDE STREET, HINDE STREET
# 4                                        NaN               5-6 DOWN STREET
# 5                                        NaN                           NaN
# 6                                        NaN                           NaN
#
#      city postcode registerdate removeddate source
# 3  LONDON  W1U 2AY          NaN         NaN     CH
# 4  LONDON      NaN          NaN         NaN     CH
# 5     NaN  W1J 7BJ          NaN         NaN     CH
# 6     NaN      NaN   31/12/1961         NaN     CH

# %% [markdown]
# These rows show four previous addresses for the organisation, and two alternative registration dates.
